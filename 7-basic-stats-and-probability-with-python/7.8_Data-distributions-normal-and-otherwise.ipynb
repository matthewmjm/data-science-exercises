# %% [markdown]
# DATA DISTRIBUTIONS NORMAL AND OTHERWISE

# %% [markdown]
# Normality Defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Making a standard normally distributed variable with 1000 observations, a mean of 0, and
# a standard deviation of 1, and putting it in a data frame.
mean = 0
sd = 1
n = 1000

# Create a DataFrame of one column rand,
# containing random numbers following normal
# distribution

df = pd.DataFrame({'rand': np.random.normal(mean, sd, n)})

# Plotting the variables in the data frame (here, just the variable "rand") as a historgram.
df.hist()

# Inline printing the histogram
plt.show()

# %% [markdown]
# When does it break?  Deviations from normality and descriptive statistics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Making two variables
rand1 = np.random.normal(50, 300, 1000)
rand2 = np.random.poisson(1, 1000)

# Sorting the values in ascending order
rand1.sort()
rand2.sort()

# Making a standard normally distributed variable with 1,000 observations,
# a mean of 0, and standard deviation of 1 that we will use as our "comparison".
norm = np.random.normal(0, 1, 1000)

# Sorting the values in acending order.
norm.sort()

# %%
# Plotting the variable rand1 against norm in qqplots
plt.plot(norm, rand1, "x")
plt.show()

# %%
# Plotting the variable rand2 against norm in qqplots
plt.plot(norm, rand2, "o")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot a histogram for rand1
plt.hist(rand1, bins=20, color='c')

# Add a vertical line at the mean
plt.axvline(rand1.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(rand1.mean() + rand1.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(rand1.mean() - rand1.std(), color='b', linestyle='dashed', linewidth=2)

# Print the historgram
plt.show()

# %%
# Plot a histogram for rand2
plt.hist(rand2, bins=20, color='c')

# Add a vertical line at the mean
plt.axvline(rand2.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(rand2.mean() + rand2.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(rand2.mean() - rand2.std(), color='b', linestyle='dashed', linewidth=2)

# Print the historgram
plt.show()

# %% [markdown]
# Bernoulli

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate a Bernoulli distribution with p = 0.5
bernoulli= np.random.binomial(1, 0.5, 1000)

# Plot on a historgram
plt.hist(bernoulli)

# Print on a histogram
plt.show()

# %% [markdown]
# Binomial

# %%
# Generate a binomial distributions with n=20 and p=0.5.
binomial = np.random.binomial(20, 0.5, 1000)

# Plot a histogram
plt.hist(binomial)

# Print the histogram
plt.show()

# %% [markdown]
# Gamma

# %%
# Generate a gamma distribution with shape =5 and scale =1
gamma = np.random.gamma(5, 1, 1000)

# Plot the historgram
plt.hist(gamma)

# Print the histogram
plt.show()

# %% [markdown]
# Poisson

# %%
# Generate a Poisson distribution with a lambda = 3
poisson = np.random.poisson(3, 1000)

# Plot the histogram
plt.hist(poisson)

# Print the histogram
plt.show()

# %% [markdown]
# Conditional Distributions

# %%
# Creating a data frame to hold the simulated ecommerce data and population
# normally distributed variable with mean 75 and standard deviation of 25.

ecommerce = pd.DataFrame()
ecommerce['spending'] = np.random.normal(75, 25, 1000)

# Plot a histogram
plt.hist(ecommerce['spending'])
plt.show()

# %%
# Adding a variable with counts of number of times visiting the site.
ecommerce['visit_count'] = np.random.randint(0, 5, 1000)

# Selecting only the cases where the visit count is greater than two and plotting those.
plt.hist(ecommerce[ecommerce['visit_count'] > 2]['spending'])
plt.show()

# %% [markdown]
# ASSIGNMENT

# %% [markdown]
# Choose 6 distributions from the list of random distributions available in NumPy, called “Distributions”

# %% [markdown]
# For each distribution:

# %% [markdown]
# 1. Generate a random variable with 100 datapoints using the code distributionvar = np.random.distributionname([arguments], 100), replacing distributionvar with an appropriate variable name and distributionname with the name of the distribution you’ve chosen, and filling in the empty space in the parentheses with your chosen values for the appropriate parameters. If you feel uncertain about how to do this, go back to the “Other Distributions” assignment for examples of code to use as a starting point.

# %% [markdown]
# 2. Graph the variable using a histogram.

# %% [markdown]
# 3. Compute the mean and standard deviation and plot them as vertical lines on the histogram.

# %% [markdown]
# 4. Evaluate whether the descriptive statistics provided useful information about the variable. Can you identify any common characteristics of the distributions that could be usefully described using the mean and/or standard deviation, versus the ones that could not?

# %% [markdown]
# ADDITIONAL ASSIGNMENT

# %% [markdown]
# 1. Generate two normally-distributed variables, one with a mean of 5 and standard deviation of 0.5, and the other with a mean of 10 and standard deviation of 1.

# %% [markdown]
# 2. Add them together to create a third variable.

# %% [markdown]
# 3. Graph the third variable using a histogram.

# %% [markdown]
# 4. Compute the mean and standard deviation and plot them as vertical lines on the histogram.

# %% [markdown]
# 5. Evaluate the descriptive statistics against the data.

# %% [markdown]
# ########ASSIGNMENTS############

# %% [markdown]
# 1.1. Uniform

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate a random variable with 100 datapoints
distributionvar = np.random.uniform(0, 100, 100)

# Plot the historgram
plt.hist(distributionvar)

# Add a vertical line at the median
plt.axvline(np.median(distributionvar), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at the mean
plt.axvline(distributionvar.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(distributionvar.mean() + distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(distributionvar.mean() - distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram
plt.show()

# %% [markdown]
# 1.2 Normal

# %%
# Generate a random variable with 100 datapoints
distributionvar = np.random.normal(50, 300, 100)

# Plot the historgram
plt.hist(distributionvar)

# Add a vertical line at the median
plt.axvline(np.median(distributionvar), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at the mean
plt.axvline(distributionvar.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(distributionvar.mean() + distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(distributionvar.mean() - distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram
plt.show()

# %% [markdown]
# 1.3 Gamma

# %%
# Generate a random variable with 100 datapoints
distributionvar = np.random.gamma(2, 2, 100)

# Plot the historgram
plt.hist(distributionvar)

# Add a vertical line at the median
plt.axvline(np.median(distributionvar), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at the mean
plt.axvline(distributionvar.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(distributionvar.mean() + distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(distributionvar.mean() - distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram
plt.show()

# %% [markdown]
# 1.4 Exponential

# %%
# Generate a random variable with 100 datapoints
distributionvar = np.random.exponential(1, 100)

# Plot the historgram
plt.hist(distributionvar)

# Add a vertical line at the median
plt.axvline(np.median(distributionvar), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at the mean
plt.axvline(distributionvar.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(distributionvar.mean() + distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(distributionvar.mean() - distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram
plt.show()

# %% [markdown]
# 1.5 Poisson

# %%
# Generate a random variable with 100 datapoints
distributionvar = np.random.poisson(5, 100)

# Plot the historgram
plt.hist(distributionvar)

# Add a vertical line at the median
plt.axvline(np.median(distributionvar), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at the mean
plt.axvline(distributionvar.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(distributionvar.mean() + distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(distributionvar.mean() - distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram
plt.show()

# %% [markdown]
# 1.6 Binomial

# %%
# Generate a random variable with 100 datapoints
distributionvar = np.random.binomial(30, .5, 100)

# Plot the historgram
plt.hist(distributionvar)

# Add a vertical line at the median
plt.axvline(np.median(distributionvar), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at the mean
plt.axvline(distributionvar.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(distributionvar.mean() + distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(distributionvar.mean() - distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram
plt.show()

# %% [markdown]
# 1.7 Bernoulli

# %%
# Generate a random variable with 100 datapoints
distributionvar = np.random.binomial(1, .5, 100)

# Plot the historgram
plt.hist(distributionvar)

# Add a vertical line at the median
plt.axvline(np.median(distributionvar), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at the mean
plt.axvline(distributionvar.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(distributionvar.mean() + distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(distributionvar.mean() - distributionvar.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram
plt.show()

# %% [markdown]
# 2.1 Generate two normally-distributed variables

# %%
varb1 = np.random.normal(5, 0.5, 1000)
varb2 = np.random.normal(10, 1, 1000)

# %% [markdown]
# 2.2 Add them together to create a third variable

# %%
varb3 = varb1 + varb2

# %% [markdown]
# 2.3 Graph the third variable using a histogram

# %%
plt.hist(varb3)
plt.show()

# %% [markdown]
# 2.4 Compute the mean and standard deviation and plot them as vertical lines

# %%
varb1 = np.random.normal(5, 0.5, 1000)
varb2 = np.random.normal(10, 1, 1000)
varb3 = varb1 + varb2
plt.hist(varb3)

# Add a vertical line at the mean
plt.axvline(varb3.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at the median
plt.axvline(np.median(varb3), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean
plt.axvline(varb3.mean() + varb3.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean
plt.axvline(varb3.mean() - varb3.std(), color='b', linestyle='dashed', linewidth=2)

# Print the histogram
plt.show()

# %% [markdown]
# 2.5 Evaluate the descriptive statistics against the data.

# %% [markdown]
# Results will vary depending on random seed.  In general, stats should show some skew.
